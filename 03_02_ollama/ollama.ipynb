# %%
# !ollama pull llama3
# Out:
# 'ollama'��(��) ���� �Ǵ� �ܺ� ����, ������ �� �ִ� ���α׷�, �Ǵ�
# ��ġ ������ �ƴմϴ�.

# %%
# 다운로드 목록 확인
# !ollama list
# Out:
# NAME             ID              SIZE      MODIFIED
# llama3:latest    365c0bd3c000    4.7 GB    28 seconds ago

# %%
# llama3 모델을 실행(인터렉티브 모드 : 게속 실행중인 상태로 나옴)
# !ollama run llama3
# Out:
# ^C

# %%
# 현재 실행중인 프로세스
# !ollama ps

# %%
# llama3 종료 (ollama 종료 안됨)
# !ollama stop llama3

# %%
# 파이썬용 ollama 클라이언트 설치
# %pip install ollama
# Out:
# Collecting ollama
#   Downloading ollama-0.6.1-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: httpx>=0.27 in c:\users\playdata\nlp\nlp_venv\lib\site-packages (from ollama) (0.28.1)
# Requirement already satisfied: pydantic>=2.9 in c:\users\playdata\nlp\nlp_venv\lib\site-packages (from ollama) (2.12.5)
# Requirement already satisfied: anyio in c:\users\playdata\nlp\nlp_venv\lib\site-packages (from httpx>=0.27->ollama) (4.12.1)
# Requirement already satisfied: certifi in c:\users\playdata\nlp\nlp_venv\lib\site-packages (from httpx>=0.27->ollama) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in c:\users\playdata\nlp\nlp_venv\lib\site-packages (from httpx>=0.27->ollama) (1.0.9)
# Requirement already satisfied: idna in c:\users\playdata\nlp\nlp_venv\lib\site-packages (from httpx>=0.27->ollama) (3.11)
# Requirement already satisfied: h11>=0.16 in c:\users\playdata\nlp\nlp_venv\lib\site-packages (from httpcore==1.*->httpx>=0.27->ollama) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\playdata\nlp\nlp_venv\lib\site-packages (from pydantic>=2.9->ollama) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\playdata\nlp\nlp_venv\lib\site-packages (from pydantic>=2.9->ollama) (2.41.5)
# Requirement already satisfied: typing-extensions>=4.14.1 in c:\users\playdata\nlp\nlp_venv\lib\site-packages (from pydantic>=2.9->ollama) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\playdata\nlp\nlp_venv\lib\site-packages (from pydantic>=2.9->ollama) (0.4.2)
# Downloading ollama-0.6.1-py3-none-any.whl (14 kB)
# Installing collected packages: ollama
# Successfully installed ollama-0.6.1
# Note: you may need to restart the kernel to use updated packages.

# %%
import ollama

response = ollama.chat(model='llama3', messages=[{'role':'user', 'content':'안녕 만나서 반가워!'}])

response
# Out:
# ChatResponse(model='llama3', created_at='2026-02-03T02:03:29.2730258Z', done=True, done_reason='stop', total_duration=4672771400, load_duration=188428700, prompt_eval_count=18, prompt_eval_duration=140948100, eval_count=35, eval_duration=4293324100, message=Message(role='assistant', content="😊 안녕하세요! 반가워요! 👋 It's great to meet you too! 😊 How can I help or chat with you today? 💬", thinking=None, images=None, tool_name=None, tool_calls=None), logprobs=None)

# %%
response.message.content
# Out:
# "😊 안녕하세요! 반가워요! 👋 It's great to meet you too! 😊 How can I help or chat with you today? 💬"

# %%
response['message']['content']
# Out:
# "😊 안녕하세요! 반가워요! 👋 It's great to meet you too! 😊 How can I help or chat with you today? 💬"

# %%
import ollama

response = ollama.chat(model='llama3', messages=[{'role':'user', 'content':'파이썬으로 퀵소트 구현해 줘'}])

response
# Out:
# ChatResponse(model='llama3', created_at='2026-02-03T02:07:07.9236009Z', done=True, done_reason='stop', total_duration=59712981500, load_duration=181301000, prompt_eval_count=25, prompt_eval_duration=1129348300, eval_count=409, eval_duration=56820974200, message=Message(role='assistant', content='Here\'s an implementation of the QuickSort algorithm in Python:\n```python\ndef quicksort(arr):\n    if len(arr) <= 1:\n        return arr\n    pivot = arr[0]\n    less = [x for x in arr[1:] if x <= pivot]\n    greater = [x for x in arr[1:] if x > pivot]\n    return quicksort(less) + [pivot] + quicksort(greater)\n\n# Example usage:\narr = [5, 2, 8, 3, 1, 6, 4]\nprint(quicksort(arr))  # Output: [1, 2, 3, 4, 5, 6, 8]\n```\nThis implementation uses the "Lomuto" partition scheme, which is a variation of the standard "Hoare" partition scheme that is slightly faster and more efficient.\n\nHere\'s how it works:\n\n1. If the input array has only one element or is empty, return it immediately (since it\'s already sorted).\n2. Choose the first element as the pivot.\n3. Create two lists: `less` contains all elements in the array that are less than or equal to the pivot, and `greater` contains all elements that are greater than the pivot.\n4. Recursively sort the `less` list and concatenate it with the pivot element (which is already sorted).\n5. Recursively sort the `greater` list and concatenate it with the result of step 4.\n\nThe time complexity of QuickSort is O(n log n) on average, although it can be O(n^2) in the worst case if the input array is not partitioned correctly. However, in practice, the algorithm is usually quite efficient and fast.\n\nNote that this implementation is not stable, meaning that equal elements may not maintain their original order in the sorted output. If stability is important, you may want to consider using a different sorting algorithm or modifying this implementation to use a stable partition scheme.', thinking=None, images=None, tool_name=None, tool_calls=None), logprobs=None)

# %%
response.message.content
# Out:
# 'Here\'s an implementation of the QuickSort algorithm in Python:\n```python\ndef quicksort(arr):\n    if len(arr) <= 1:\n        return arr\n    pivot = arr[0]\n    less = [x for x in arr[1:] if x <= pivot]\n    greater = [x for x in arr[1:] if x > pivot]\n    return quicksort(less) + [pivot] + quicksort(greater)\n\n# Example usage:\narr = [5, 2, 8, 3, 1, 6, 4]\nprint(quicksort(arr))  # Output: [1, 2, 3, 4, 5, 6, 8]\n```\nThis implementation uses the "Lomuto" partition scheme, which is a variation of the standard "Hoare" partition scheme that is slightly faster and more efficient.\n\nHere\'s how it works:\n\n1. If the input array has only one element or is empty, return it immediately (since it\'s already sorted).\n2. Choose the first element as the pivot.\n3. Create two lists: `less` contains all elements in the array that are less than or equal to the pivot, and `greater` contains all elements that are greater than the pivot.\n4. Recursively sort the `less` list and concatenate it with the pivot element (which is already sorted).\n5. Recursively sort the `greater` list and concatenate it with the result of step 4.\n\nThe time complexity of QuickSort is O(n log n) on average, although it can be O(n^2) in the worst case if the input array is not partitioned correctly. However, in practice, the algorithm is usually quite efficient and fast.\n\nNote that this implementation is not stable, meaning that equal elements may not maintain their original order in the sorted output. If stability is important, you may want to consider using a different sorting algorithm or modifying this implementation to use a stable partition scheme.'

# %%
sponse = ollama.chat(model='llama3', messages=[{'role':'user', 'content':"""다음 텍스트 요약해줘 :인류 역사의 흐름 속에서 기술의 발전은 놀라운 속도로 진행되어 왔으며, 그 결과 현대 사회는 정보화 시대에 접어들어 엄청난 양의 데이터를 생성하고 처리하는 단계에 이르렀습니다. 특히, 인터넷과 컴퓨터 기술의 발달은 전 세계를 연결하는 거대한 네트워크를 형성하여 사람들 간의 소통 방식을 근본적으로 바꾸어 놓았습니다. 초기의 아날로그 통신 기술은 디지털 기술로 대체되면서 정보의 전달 속도와 정확성이 극적으로 향상되었으며, 이것이 오늘날 우리가 누리는 다양한 온라인 서비스와 플랫폼의 기반이 되었습니다.
예를 들어, 과거에는 손편지나 전화 통화가 주를 이루었으나, 현재는 이메일, 소셜 미디어, 화상 통화, 메시징 앱 등 다양한 디지털 채널을 통해 실시간으로 전 세계 어디서나 소통이 가능합니다. 이와 같은 기술적 진보는 비즈니스, 교육, 의료, 엔터테인먼트 등 여러 분야에 혁신을 불러왔으며, 원격 근무와 온라인 학습 같은 새로운 라이프스타일을 가능하게 했습니다.
더불어 인공지능과 머신러닝 기술의 발전은 데이터 분석과 자동화를 통해 많은 일들을 더 효율적이고 정밀하게 처리할 수 있게 해 줍니다. 인공지능은 이미지 인식, 자연어 처리, 자율 주행차, 개인 맞춤형 추천 시스템 등 우리 일상생활 곳곳에 스며들어 있으며, 앞으로도 그 영향력은 더욱 커질 것으로 전망됩니다. 그러나 이러한 변화는 동시에 개인정보 보호, 윤리적 문제, 기술 격차와 같은 사회적 이슈도 동반하고 있습니다.
한편, 지속 가능한 발전과 환경 보호에 대한 관심도 점차 높아지고 있는데, 이는 기후 변화와 자원 고갈 문제에 대한 인식이 확대되었기 때문입니다. 각국은 친환경 에너지 사용을 확대하고 탄소 배출을 줄이기 위한 정책을 시행하며, 기업들도 ESG(Environmental, Social, Governance) 경영을 통해 사회적 책임을 다하려는 움직임이 활발합니다. 기술 역시 이러한 목표를 지원하는 역할을 하며, 예를 들어 스마트 그리드, 재생 에너지 관리 시스템, 전기 자동차 등이 발전하고 있습니다.
이와 같은 복합적인 사회 변화 속에서 개인과 공동체는 새로운 기회와 도전을 경험하며 적응해 나가고 있습니다. 교육에서는 디지털 리터러시가 필수 요소로 자리 잡았으며, 평생 학습이 강조되고 있습니다. 건강 관리 분야에서는 웨어러블 디바이스와 원격 진료가 보편화되어 개인 맞춤형 건강 관리가 가능해졌습니다. 또한 문화와 예술은 디지털 미디어를 통해 전 세계적으로 공유되고 교류되며, 새로운 창작과 표현의 장을 열어가고 있습니다.
끝으로, 이러한 변화들로 인해 우리는 끊임없이 배우고 변화에 대응해야 하는 시대에 살고 있다는 점을 기억하는 것이 중요합니다. 기술의 이점과 위험성을 균형 있게 이해하고, 인간 중심의 가치와 윤리를 기반으로 한 발전 방향을 모색하는 것이 앞으로의 사회가 나아가야 할 길일 것입니다.
"""}])

# %%
print(response.message.content)
# Out:
# Here's an implementation of the QuickSort algorithm in Python:
# ```python
# def quicksort(arr):
#     if len(arr) <= 1:
#         return arr
#     pivot = arr[0]
#     less = [x for x in arr[1:] if x <= pivot]
#     greater = [x for x in arr[1:] if x > pivot]
#     return quicksort(less) + [pivot] + quicksort(greater)
#
# # Example usage:
# arr = [5, 2, 8, 3, 1, 6, 4]
# print(quicksort(arr))  # Output: [1, 2, 3, 4, 5, 6, 8]
# ```
# This implementation uses the "Lomuto" partition scheme, which is a variation of the standard "Hoare" partition scheme that is slightly faster and more efficient.
#
# Here's how it works:
#
# 1. If the input array has only one element or is empty, return it immediately (since it's already sorted).
# 2. Choose the first element as the pivot.
# 3. Create two lists: `less` contains all elements in the array that are less than or equal to the pivot, and `greater` contains all elements that are greater than the pivot.
# 4. Recursively sort the `less` list and concatenate it with the pivot element (which is already sorted).
# 5. Recursively sort the `greater` list and concatenate it with the result of step 4.
#
# The time complexity of QuickSort is O(n log n) on average, although it can be O(n^2) in the worst case if the input array is not partitioned correctly. However, in practice, the algorithm is usually quite efficient and fast.
#
# Note that this implementation is not stable, meaning that equal elements may not maintain their original order in the sorted output. If stability is important, you may want to consider using a different sorting algorithm or modifying this implementation to use a stable partition scheme.
