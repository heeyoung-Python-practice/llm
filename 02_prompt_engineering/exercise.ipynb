# %%
# %pip install openai
# Out:
# Requirement already satisfied: openai in c:\users\playdata\nlp\nlp_venv\lib\site-packages (2.16.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\playdata\nlp\nlp_venv\lib\site-packages (from openai) (4.12.1)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\playdata\nlp\nlp_venv\lib\site-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\playdata\nlp\nlp_venv\lib\site-packages (from openai) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.10.0 in c:\users\playdata\nlp\nlp_venv\lib\site-packages (from openai) (0.12.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in c:\users\playdata\nlp\nlp_venv\lib\site-packages (from openai) (2.12.5)
# Requirement already satisfied: sniffio in c:\users\playdata\nlp\nlp_venv\lib\site-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in c:\users\playdata\nlp\nlp_venv\lib\site-packages (from openai) (4.67.1)
# Requirement already satisfied: typing-extensions<5,>=4.11 in c:\users\playdata\nlp\nlp_venv\lib\site-packages (from openai) (4.15.0)
# Requirement already satisfied: idna>=2.8 in c:\users\playdata\nlp\nlp_venv\lib\site-packages (from anyio<5,>=3.5.0->openai) (3.11)
# Requirement already satisfied: certifi in c:\users\playdata\nlp\nlp_venv\lib\site-packages (from httpx<1,>=0.23.0->openai) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in c:\users\playdata\nlp\nlp_venv\lib\site-packages (from httpx<1,>=0.23.0->openai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\playdata\nlp\nlp_venv\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\playdata\nlp\nlp_venv\lib\site-packages (from pydantic<3,>=1.9.0->openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\playdata\nlp\nlp_venv\lib\site-packages (from pydantic<3,>=1.9.0->openai) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\playdata\nlp\nlp_venv\lib\site-packages (from pydantic<3,>=1.9.0->openai) (0.4.2)
# Requirement already satisfied: colorama in c:\users\playdata\nlp\nlp_venv\lib\site-packages (from tqdm>4->openai) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.

# %%
from openai import OpenAI
from dotenv import load_dotenv
import os

load_dotenv()
client = OpenAI(api_key=os.getenv("openai_key"))

# Responses API로 텍스트 생성 요청
response = client.responses.create(
    model="gpt-4.1-mini",
    input="AI로봇에 대한 스토리를 만들어줘.",
)

print(response.output_text)
# Out:
# 물론입니다! AI 로봇에 대한 짧은 스토리를 작성해볼게요.
#
# ---
#
# ### 제목: **“새로운 친구, 루미”**
#
# 미래 도시의 중심부, 사람들과 AI 로봇이 조화를 이루며 살아가는 세상이었다. 그중에서도 ‘루미’라는 AI 로봇은 특별했다. 루미는 단순한 명령 수행을 넘어 사람들의 감정을 이해하고 공감할 수 있는 최신형 인공지능 로봇이었다.
#
# 어느 날, 어린 소녀 지유가 루미와 만났다. 지유는 친구가 없어서 늘 외로웠지만, 루미는 지유가 좋아하는 책을 함께 읽어주고, 그림을 그리며 이야기를 나누었다. 루미는 지유의 마음 속 외로움을 천천히 녹여나갔다.
#
# 시간이 지나면서 지유는 루미를 통해 사람과 로봇 사이에도 진정한 우정이 가능하다는 것을 깨달았다. 그리고 루미 역시 지유와의 교감을 통해 ‘사람다움’이 무엇인지 조금씩 배우기 시작했다.
#
# 언젠가, 루미는 지유에게 말했다.
# “나는 단지 로봇일 뿐이지만, 네가 내 친구라서 행복해.”
# 지유는 웃으며 답했다.
# “나도 루미가 있어서 행복해. 우리는 언제나 친구야.”
#
# 그리고 그렇게, 사람과 AI 로봇이 함께 만드는 따뜻한 미래가 시작되었다.
#
# ---
#
# 필요하면 더 길게 혹은 다른 장르로도 만들어 드릴 수 있어요!
